# %% [markdown]
# <a href="https://colab.research.google.com/github/SimonHegelich/Datenanalyse/blob/main/Notebook_Linear_Discriminant_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programmierübung: <font color='darkorange'> Linear Discriminant Analysis</font>
#
# ##### <font color='darkorange'> Datenanalyse, Sommersemester 2022, Lehrstuhl für Political Data Science </font>

# %% [markdown]
# Zunächst laden wir den Datensatz:
# [Link zu den Datensätzen](https://www.statlearning.com/resources-first-edition) Wir möchten den Datensatz SMarket nutzen, der Teil der ISLR Library ist. Diese ISLR (Introduction to Statistical Learning) Library wird von den Autoren des Lehrbuches angeboten.
#
# Weitere Informationen dazu findet ihr hier:
# [Informationen zum Datenpackage ISLR](https://cran.r-project.org/web/packages/ISLR/ISLR.pdf)
#
# In dem Notebook hier findet ihr einige Aufgaben, die eventuell etwas schwieriger sind. Aber: Wenn ihr euch das Lab auf Seite 154 ff. im Buch anschaut, sollte es kein Problem sein!

# %%
# Smarket data, which is part of the ISLR library
install.packages("ISLR")
library(ISLR)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Überblick schaffen
summary(Smarket)
dim(Smarket)
# Out:
#       Year           Lag1                Lag2                Lag3
#  Min.   :2001   Min.   :-4.922000   Min.   :-4.922000   Min.   :-4.922000
#  1st Qu.:2002   1st Qu.:-0.639500   1st Qu.:-0.639500   1st Qu.:-0.640000
#  Median :2003   Median : 0.039000   Median : 0.039000   Median : 0.038500
#  Mean   :2003   Mean   : 0.003834   Mean   : 0.003919   Mean   : 0.001716
#  3rd Qu.:2004   3rd Qu.: 0.596750   3rd Qu.: 0.596750   3rd Qu.: 0.596750
#  Max.   :2005   Max.   : 5.733000   Max.   : 5.733000   Max.   : 5.733000
#       Lag4                Lag5              Volume           Today
#  Min.   :-4.922000   Min.   :-4.92200   Min.   :0.3561   Min.   :-4.922000
#  1st Qu.:-0.640000   1st Qu.:-0.64000   1st Qu.:1.2574   1st Qu.:-0.639500
#  Median : 0.038500   Median : 0.03850   Median :1.4229   Median : 0.038500
#  Mean   : 0.001636   Mean   : 0.00561   Mean   :1.4783   Mean   : 0.003138
#  3rd Qu.: 0.596750   3rd Qu.: 0.59700   3rd Qu.:1.6417   3rd Qu.: 0.596750
# ...

# %%
pairs(Smarket, main = "Überblick über den Datensatz")
plot(Smarket$Volume, main = "Die Variable Volume")
# Out:
# plot without title
# Plot with title “Die Variable Volume”

# %% [markdown]
# ## <font color='blue'> Aufgabe 1)
#
# <font color='blue'>
# Wir möchten nun zuerst nochmals eine logistische Regression fitten. Als abhängige Variable möchten wir nun $Direction$ nehmen, als unabhängige Variable $Lag1$.
#
# a) Zunächst plotten wir diese Variablen zusammen in einem Plot. Achtet auf die richtigen Achsen.
#
# b) Unterteilt die Daten in Trainings- und Testset.
#
# c) Nun möchten wir mit diesen Variablen nochmal eine logistische Regression auf den Trainingsdaten fitten. Gebt von dieser Regression ein $summary$ aus.
#
# d) Als Nächstes wollen wir mit der gefitteten Regression die Test-Werte vorhersagen.
#
# e) Gib nun die Kreuztabelle an.
#
#
# (Dazu könnt ihr auch nochmal im Notebook von letzter Woche nachsehen.)

# %%
#a)

# %%
#b)

# %%
#c)

# %%
#d)

# %%
#e)

# %% [markdown]
# ## <font color='blue'> Aufgabe 2)
#
# <font color='blue'>
# Jetzt wollen wir das eigentliche Thema dieser Woche, die LDA berechnen.
#
# a) Nutze den Befehl $lda$ und fitte eine Linear Discriminant Analysis. Nehme hierfür wieder die abhängige Variable $Direction$ und die unabhängige Variable $Lag1$ aus den Trainingsdaten.
#
# b) Nun wollen wir mit der gefitteten LDA wieder die Testwerte vorhersagen. (Nutze dafür die Funktion $predict$.)
#
# c) Was genau gibt uns die Funktion $predict$ aus? Untersuche das u.a. mit den Befehlen $names()$ und $summary()$. Auch im Buch kann dazu einiges nachgelesen werden.
#
# d) Jetzt möchten wir auch hierfür die Kreuztabelle aufstellen.
#
# e) Jetzt möchten wir das ganze noch für 2 unabhängige Variablen machen. Dazu halten wir uns wieder an das Buch und nehmen die Variablen $Lag1$ und $Lag2$.

# %%
# Zunächst brauchen wir noch das Package $MASS$

install.packages("MASS")
library("MASS")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#Datenstruktur
str(Smarket)
# Out:
# 'data.frame':	1250 obs. of  9 variables:
#  $ Year     : num  2001 2001 2001 2001 2001 ...
#  $ Lag1     : num  0.381 0.959 1.032 -0.623 0.614 ...
#  $ Lag2     : num  -0.192 0.381 0.959 1.032 -0.623 ...
#  $ Lag3     : num  -2.624 -0.192 0.381 0.959 1.032 ...
#  $ Lag4     : num  -1.055 -2.624 -0.192 0.381 0.959 ...
#  $ Lag5     : num  5.01 -1.055 -2.624 -0.192 0.381 ...
#  $ Volume   : num  1.19 1.3 1.41 1.28 1.21 ...
#  $ Today    : num  0.959 1.032 -0.623 0.614 0.213 ...
#  $ Direction: Factor w/ 2 levels "Down","Up": 2 2 1 2 2 2 1 2 2 2 ...

# %%
#a)

# %%
#b)

# %%
#c)

# %%
#d)

# %%
#e)

# %% [markdown]
# ## <font color='blue'> Aufgabe 3)
#
# <font color='blue'>
# Nun wollen wir abschließend noch eine QDA berechnen.
# Im Buch findet ihr dazu Details ab "4.6.4 Quadratic Discriminant Analysis" ab S. 163.
# Als unabhängige Variable nehmen wir Lag1 und Lag2 und als abhängige Variable Direction.
#
# a) Fitte die QDA mit dem Befehl $qda$. Zunächst bitte wieder in Trainings- und Testset unterteilen.
#
# b) Sage mit der gefitteten QDA die Testdaten voraus.
#
# c) Gibt die Kreuztabelle aus.

# %%
#Package installieren
install.packages("MASS")
library("MASS")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
#a)

# %%
#b)

# %%
#c)

# %% [markdown]
# ## <font color='blue'> Aufgabe 4)
#
# <font color='blue'>
# Vergleich nun bitte die gefitteten Modelle. Was fällt dir auf? Welches Modell scheint das Beste zu sein?

# %% [markdown]
# ### <font color='darkorange'> Zugehörige Seiten in der Pflichtlektüre: </font>
# Ab "4.6 Lab: Logistische Regression, LDA, QDA, and KNN", S.154; genauer: "4.6.3 Linear Discriminant Analysis", S. 161
